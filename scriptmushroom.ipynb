# %%
library('caret')
library('dplyr')
datos<-read.csv('mushrooms.csv')
#str(datos)
datos <- select(datos, -veil.type) #eliminamos la columna veil.type
#str(datos)
#datos$class
#length(which(datos$class=='p'))
class = ifelse(datos$class=='e',"Comestible", "Venenosa")
datos$class = as.factor(class)
names(datos)[1]="class"
t.caret = train(class~., data = datos, method = "rpart2", tuneLength=6)
t.caret
plot(t.caret$finalModel)
text(t.caret$finalModel, pretty=F )
# Out:
# CART
#
# 8124 samples
#   21 predictor
#    2 classes: 'Comestible', 'Venenosa'
#
# No pre-processing
# Resampling: Bootstrapped (25 reps)
# Summary of sample sizes: 8124, 8124, 8124, 8124, 8124, 8124, ...
# Resampling results across tuning parameters:
#
#   maxdepth  Accuracy   Kappa
#   1         0.8856277  0.7724048
#   2         0.9425997  0.8851168
#   3         0.9673677  0.9345760
#   4         0.9775163  0.9549593
#   5         0.9849666  0.9698697
#   6         0.9853672  0.9706733
#
# Accuracy was used to select the optimal model using the largest value.
# The final value used for the model was maxdepth = 6.
# plot without title
